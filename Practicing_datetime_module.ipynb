# %%
# Today , I am practicing datetime module in pyhton !!
# Print Today's date and time
import datetime
today=datetime.datetime.now()
print(today)
# Out:
# 2026-07-18 06:10:30.983853

# %%
# To Print today's date
import datetime
date=datetime.date.today()
print(date)
# Out:
# 2026-07-18

# %%
# To Print the current time
import datetime
print(datetime.datetime.now().time())
# Out:
# 06:12:51.846147

# %%
# To print only the current year.
import datetime
current_year = datetime.datetime.now()
print(current_year.year)
# Out:
# 2026

# %%
#TO Print only the current month.
import datetime
current_month = datetime.datetime.now()
print(current_month.month)
# Out:
# 7

# %%
# To Print today's day name
import datetime
day_name= datetime.datetime.now()
print(day_name.strftime("%A"))
# Out:
# Saturday

# %%
# To Print the month name.
import datetime
month_name = datetime.datetime.now()
print(month_name.strftime('%B'))
# Out:
# July

# %%
# To Create your birthday using datetime.date().
import datetime
birthday = datetime.date(2007 , 5 , 25)
print(f"My Birthdate is {birthday} !!")
# Out:
# My Birthdate is 2007-05-25 !!

# %%
# To Create an alarm time of 6:30 AM.
import datetime
alarm = datetime.time(6 , 30)
print(f"My alarm is set for {alarm} A.M.")
# Out:
# My alarm is set for 06:30:00 A.M.

# %%
# To Create a date and time for your next exam.
import datetime
exam_date = datetime.datetime(2026, 8, 18, 9,30)
print(f"My Next exam is on {exam_date} A.M.")
# Out:
# My Next exam is on 2026-08-18 09:30:00 A.M.

# %%
# To Print today's date in the format DD-MM-YYYY.
import datetime
today= datetime.date(2026, 7, 18)
print(today.strftime("%d-%m-%Y"))
# Out:
# 18-07-2026
