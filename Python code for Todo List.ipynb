# %%
to_do_list=["Exercise","Python Learning","IIRS notes","book reading"]
tasks_completed=[]
tasks_left=[]

task1=str(input("Have you completed the Exercise task(yes/no): "))
if task1=="yes":
  tasks_completed.append("Exercise")
else:
  tasks_left.append("Exercise")

task2=str(input("Have you completed the Python Learning task(yes/no): "))
if task2=="yes":
  tasks_completed.append("Python Learning")
else:
  tasks_left.append("Python Learning")

task3=str(input("Have you completed the IIRS notes task(yes/no): "))
if task3=="yes":
  tasks_completed.append("IIRS notes")
else:
  tasks_left.append("IIRS notes")

task4=str(input("Have you completed the book reading task(yes/no): "))

if task4=="yes":
  tasks_completed.append("book reading")
else:
  tasks_left.append("book reading")

print("Tasks completed at the end of the day are:",tasks_completed)
print("Tasks not completed at the end of the day are:",tasks_left)
# Out:
# Have you completed the Exercise task(yes/no): yes
# Have you completed the Python Learning task(yes/no): yes
# Have you completed the IIRS notes task(yes/no): no
# Have you completed the book reading task(yes/no): no
# Tasks completed at the end of the day are: ['Exercise', 'Python Learning']
# Tasks not completed at the end of the day are: ['IIRS notes', 'book reading']
