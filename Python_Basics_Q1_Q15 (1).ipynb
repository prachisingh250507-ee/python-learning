# %%
#program to print the following:
# Hello, Python!
# Welcome to Programming.

print("Hello Python!\nWelcome To Programming.")
# Out:
# Hello Python!
# Welcome To Programming.

# %%
#a program to input your name, age, and branch, then display them in a neat format.
name=str(input("Enter your name:"))
age=int(input("Enter your age:"))
branch=str(input("Enter your branch:"))
print("Name:",name)
print("Age:",age)
print("Branch:",branch)
# Out:
# Enter your name:Prachi
# Enter your age:19
# Enter your branch:B.Tech Electrical
# Name: Prachi
# Age: 19
# Branch: B.Tech Electrical

# %%
#to find area of rectangle
len=float(input("Enter the length:"))
wid=float(input("Enter the width:"))
area=len*wid
print("Area of rectangle is:",area)
# Out:
# Enter the length:10
# Enter the width:20
# Area of rectangle is: 200.0

# %%
#To calculate the area and circumference of rectangle
rad=float(input("Enter the radius of the circle: "))
area=3.14*rad*rad
circum=2*3.14*rad
print("Area of the circle with given radius",rad,"is:",area)
print("Circumference of the circle with given radius",rad,"is:",circum)
# Out:
# Enter the radius of the circle: 5
# Area of the circle with given radius 5.0 is: 78.5
# Circumference of the circle with given radius 5.0 is: 31.400000000000002

# %%
# program to swap two numbers using: a temporary variable
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
print("Before swapping:")
print("First number:",num1)
print("Second number:",num2)
temp=num1
num1=num2
num2=temp
print("After swapping:")
print("First number:",num1)
print("Second number:",num2)
# Out:
# Enter the first number:5
# Enter the second number:8
# Before swapping:
# First number: 5
# Second number: 8
# After swapping:
# First number: 8
# Second number: 5

# %%
#program to swap two numbers without using: a temporary variable
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
print("Before swapping:")
print("First number:",num1)
print("Second number:",num2)

# Swap logic using arithmetic operators
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2

print("\nAfter swapping:")
print("First number:",num1)
print("Second number:",num2)
# Out:
# Enter the first number:10
# Enter the second number:15
# Before swapping:
# First number: 10
# Second number: 15
#
# After swapping:
# First number: 15
# Second number: 10

# %%
# Write a program to convert temperature.
# Celsius → Fahrenheit
# Fahrenheit → Celsius
choice=int(input("Enter your choice\n1.Celsius to fahrenheit\n2.Fahrenheit to celsius\nEnter(1/2):"))
temp=float(input("Enter the temprature: "))

if choice==1:
  ans=(temp*1.8)+32
  print("temprature in Fahrenheit: ",ans)

elif choice==2:
  ans=(temp-32)/1.8
  print("temprature in Celsius: ",ans)

else:
  print("Invalid Input!\nPlease Enter either 1 or 2 according to the requirement!")
# Out:
# Enter your choice
# 1.Celsius to fahrenheit
# 2.Fahrenheit to celsius
# Enter(1/2):1
# Enter the temprature: 100
# temprature in Fahrenheit:  212.0

# %%
# A program to calculate Simple Interest.
p=float(input("Enter the principal amount: "))
r=float(input("Enter the rate of interest: "))
t=float(input("Enter the time period: "))
si=(p*r*t)/100
print("Simple Interest",si)
# Out:
# Enter the principal amount: 5000
# Enter the rate of interest: 2
# Enter the time period: 5
# Simple Interest 500.0

# %%
# Program to convert minutes into hours and remaining minutes.
min=int(input("Enter the minutes: "))
hrs=int(min/60)
mins=min%60
print("",hrs,"hours",mins,"minutes")
# Out:
# Enter the minutes: 150
#  2 hours 30 minutes

# %%
# Program to check whether a number is positive, negative, or zero.
num=float(input("Enter the number:"))
if num<0:
  print("Given number is a negative number !")
elif num>0:
  print("Given number is a positive number !")
else:
  print("Given number is a zero !")
# Out:
# Enter the number:-0.1
# Given number is a negative number !

# %%
# Program to check whether a number is even or odd.
num=int(input("Enter the number:"))
if num%2==0:
  print("Given number is an even number !")
else:
  print("Given number is an odd number !")
# Out:
# Enter the number:4
# Given number is an even number !

# %%
# Program to find the largest among three numbers.
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
num3=int(input("Enter the third number:"))
if num1>num2 and num1>num3:
  print("The largest number is the first one",num1)
elif num2>num1 and num2>num3:
  print("The largest number is  the second one",num2)
else:
  print("The largest number is  the third one",num3)
# Out:
# Enter the first number:4
# Enter the second number:6
# Enter the third number:2
# The largest number is  the second one 6

# %%
# Program to check whether a year is a leap year.
year=int(input("Enter the year:"))
if year%4==0:
  if year%100==0:
    if year%400==0:
      print("Given year is a leap year !")
    else:
      print("Given year is not a leap year !")
  else:
    print("Given year is a leap year !")
# Out:
# Enter the year:1900
# Given year is not a leap year !

# %%
# Program to check whether a character is:Vowel or Consonant
ch=str(input("Enter the character:"))
vow=["a","e","i","o","u"]
if ch in vow:
  print("Given charcter is a vowel !")
else:
  print("Given character is a consonant !")
# Out:
# Enter the character:p
# Given character is a consonant !

# %%
# Write a program to calculate electricity bill.
# Example rules:
# First 100 units → ₹5/unit
# Next 100 units → ₹7/unit
# Remaining units → ₹10/unit
unit=int(input("Enter the number of units consumed:"))
if unit<=100:
  bill=unit*5
  print("Your Electricity bill is:", bill)
elif unit<=200:
  bill=(100*5+(unit-100)*7)
  print("Your Electricity bill is:", bill)
else:
  bill=(100*5+100*7+(unit-200)*10)
  print("Your Electricity bill is:", bill)
# Out:
# Enter the number of units consumed:300
# Your Electricity bill is: 2200

# %%
# Write a grading system.
# 90–100 → A+
# 80–89 → A
# 70–79 → B
# 60–69 → C
# Below 60 → Fail
marks=int(input("Enter the marks:"))
if 90<=marks<=100:
  print("CONGRATULATIONS !!\nYour Grade is A+")
  print("Excellent Performance !")
elif 80<=marks<=89:
  print("Very Good !!\nYour Grade is A")
  print("Keep it UP")
elif 70<=marks<=79:
  print("Your Grade is B")
elif 60<=marks<=69:
  print("Your Grade is C")
elif 0<=marks<60:
  print("FAIL !!")
else:
  print("INVALID MARKS\nPlease Enter marks between (0-100)")
# Out:
# Enter the marks:95
# CONGRATULATIONS !!
# Your Grade is A+
# Excellent Performance !
